# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %% [markdown]
# # 1-Answer

# %%
df.shape
# Out:
# (23678, 21)

# %% [markdown]
# # 2- Answer:

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# # 3- Answer:

# %%
df[df.isnull().all(axis=1)].index[0]
# Out:
# 31

# %% [markdown]
# # 4- Answer:

# %%
#df.isnull().sum()*100/len(df)
df[df.isnull().all(axis=1)].index[0]*100/len(df)
# Out:
# 0.1309232198665428

# %%
df.dropna(axis=0)
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 2        Abbotsford  25 Bloomburg St    2.0    h  1035000.0      S
# 4        Abbotsford     5 Charles St    3.0    h  1465000.0     SP
# 6        Abbotsford      55a Park St    4.0    h  1600000.0     VB
# 11       Abbotsford     124 Yarra St    3.0    h  1876000.0      S
# 14       Abbotsford    98 Charles St    2.0    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 19845    Whittlesea    30 Sherwin St    3.0    h   601000.0      S
# 19846  Williamstown      75 Cecil St    3.0    h  1050000.0     VB
# 19847  Williamstown    2/29 Dover Rd    1.0    u   385000.0     SP
# 19849       Windsor  201/152 Peel St    2.0    u   560000.0     PI
# 19852    Yarraville  54 Pentland Pde    6.0    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 2             Biggin  04-02-2016       2.5    3067.0  ...       1.0  0.0
# ...

# %% [markdown]
# # 5- Answer:

# %%
df.isnull().sum()
# Out:
# Suburb             131
# Address            131
# Rooms              131
# Type               131
# Price             5282
# Method             131
# SellerG            131
# Date               131
# Distance           132
# Postcode           132
# Bedroom2          4612
# Bathroom          4615
# Car               4757
# Landsize          6268
# BuildingArea     13660
# YearBuilt        12138
# CouncilArea       8022
# Lattitude         4435
# Longtitude        4435
# Regionname         132
# Propertycount      132
# dtype: int64

# %% [markdown]
# # 6- Answer:

# %%
df.isnull().sum()*100/len(df)
# Out:
# Suburb            0.553256
# Address           0.553256
# Rooms             0.553256
# Type              0.553256
# Price            22.307627
# Method            0.553256
# SellerG           0.553256
# Date              0.553256
# Distance          0.557480
# Postcode          0.557480
# Bedroom2         19.477996
# Bathroom         19.490666
# Car              20.090379
# Landsize         26.471830
# BuildingArea     57.690683
# YearBuilt        51.262776
# CouncilArea      33.879551
# Lattitude        18.730467
# Longtitude       18.730467
# Regionname        0.557480
# Propertycount     0.557480
# dtype: float64

# %% [markdown]
# # 7- Answer:

# %%
df[df.isnull().any(axis=1)]
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 5        Abbotsford    40 Federation La    3.0    h   850000.0     PI
# 7        Abbotsford        16 Maugie St    4.0    h        NaN     SN
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %% [markdown]
# # 8- Answer:

# %%
df.isnull().values.any(axis=0)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %% [markdown]
# # 9- Answer:

# %%
df_null=df.isnull().mean().round(4)*100
df_null
# Out:
# Suburb            0.55
# Address           0.55
# Rooms             0.55
# Type              0.55
# Price            22.31
# Method            0.55
# SellerG           0.55
# Date              0.55
# Distance          0.56
# Postcode          0.56
# Bedroom2         19.48
# Bathroom         19.49
# Car              20.09
# Landsize         26.47
# BuildingArea     57.69
# YearBuilt        51.26
# CouncilArea      33.88
# Lattitude        18.73
# Longtitude       18.73
# Regionname        0.56
# Propertycount     0.56
# dtype: float64

# %%
df.drop(['BuildingArea','YearBuilt','CouncilArea'],axis=1,inplace=True)

# %% [markdown]
# # 10- Answer:

# %%
df_row=df.isnull().sum(axis=1)>5
df_row.dropna(axis=0,inplace=True)
print(round(100*(1-df.count()/len(df)),2))
# Out:
# Suburb            0.55
# Address           0.55
# Rooms             0.55
# Type              0.55
# Price            22.31
# Method            0.55
# SellerG           0.55
# Date              0.55
# Distance          0.56
# Postcode          0.56
# Bedroom2         19.48
# Bathroom         19.49
# Car              20.09
# Landsize         26.47
# Lattitude        18.73
# Longtitude       18.73
# Regionname        0.56
# Propertycount     0.56
# dtype: float64

# %% [markdown]
# # 11- Answer:

# %%
df.isnull().mean().round(4)*100
# Out:
# Suburb            0.55
# Address           0.55
# Rooms             0.55
# Type              0.55
# Price            22.31
# Method            0.55
# SellerG           0.55
# Date              0.55
# Distance          0.56
# Postcode          0.56
# Bedroom2         19.48
# Bathroom         19.49
# Car              20.09
# Landsize         26.47
# Lattitude        18.73
# Longtitude       18.73
# Regionname        0.56
# Propertycount     0.56
# dtype: float64

# %% [markdown]
# # 12- Answer:

# %% [markdown]
# When we select the 'Price' column as target variable then firstly we deal with the mesing values. If
# we want to not drop the meassing values, then we go to the mean/median.

# %%
df['Price'].replace(np.NaN, df['Price'].mean()).head()
# Out:
# 0    1.056697e+06
# 1    1.480000e+06
# 2    1.035000e+06
# 3    1.056697e+06
# 4    1.465000e+06
# Name: Price, dtype: float64

# %% [markdown]
# # 13- Answer:

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (23678, 18)
# Suburb            131
# Address           131
# Rooms             131
# Type              131
# Price            5282
# Method            131
# SellerG           131
# Date              131
# Distance          132
# Postcode          132
# Bedroom2         4612
# Bathroom         4615
# Car              4757
# Landsize         6268
# Lattitude        4435
# Longtitude       4435
# Regionname        132
# Propertycount     132
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (13518, 18)
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# # 14- Answer:

# %% [markdown]
# Three columns are removed from this data set.14% of columns are remover from this data set.

# %% [markdown]
# # 15- Answer:

# %% [markdown]
# 42% rows are removed to doing this above the whole process. The amount of data that are removed from
# this data set is not good because when we want to obtain a good result from any data set maximum of
# 10-15% of missing data can remove. So this is not justified for this data set.
